# %% [markdown]
# # <en><center>Python Visualizations</center><en>

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %% [markdown]
# ## Table of Contents
# - [Libraries](#Libraries)
# - [Matplotlib](#Matplotlib)
#     - [Matplotlib Exercises](#Matplotlib-Exercises)
# - [Seaborn Visualizations](#Seaborn-Visualizations)
#     - [Distribution Plots](#Distribution-Plots)
#     - [Categorical Plots](#Categorical-Plots)
#     - [Matrix Plots](#Matrix-Plots)
#     - [Grids](#Grids)
#     - [Regression Plots](#Regression-Plots)
#     - [Style & Color](#Style-&-Color)
#     - [Seaborn Visualization Practice](#Seaborn-Visualization-Practice)
# - [Pandas Data Visualization](#Pandas-Data-Visualization)
# - [Plotly & Cufflinks](#Plotly-&-Cufflinks)

# %% [markdown]
# ## <en><center>Libraries</center></en>

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## <en><center>Matplotlib</center></en>

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %% [markdown]
# ### Dataset

# %%
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ### Functional Method

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %%
plt.plot(x,y, "r-")
plt.xlabel("X label")
plt.ylabel("Y label")
plt.title("Title")

plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"r")

plt.subplot(1,2,2)
plt.plot(y,x,"b")
plt.show()

# %% [markdown]
# ### Object Oriented Method

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %%
fig = plt.figure()


axes = fig.add_axes([0.1,0.1,0.8,0.8])

axes.plot(x,y)
axes.set_xlabel("X label")
axes.set_ylabel("Y label")
axes.set_title("Title")

plt.show()

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x,y)
axes1.set_title("Larger Plot")

axes2.plot(y,x)
axes2.set_title("Smaller Plot")
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %%
fig,axes = plt.subplots(nrows= 1,ncols=2)

#axes.plot(x,y)

# %% [markdown]
# plt.subplots is just a subplot manager for plt.fig

# %%
fig,axes = plt.subplots(nrows=2,ncols=3)

#axes.plot(x,y)
plt.show()
plt.tight_layout()

# %% [markdown]
# The axes object can be unpacked with tuple unpacking and when unpacked is exactly the axes1 and axes2 veriables from the example above

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

for current_ax in axes:
    current_ax.plot(x,y)

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

axes[0].plot(x,y)
axes[0].set_title("First Plot")

axes[1].plot(y,x)
axes[1].set_title("Second Plot")

plt.tight_layout()

# %% [markdown]
# Figure Size & DPI

# %%
fig = plt.figure(figsize=(8,2))

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fix,axes = plt.subplots(nrows = 2, ncols = 1, figsize = (8,2))

axes[0].plot(x,y)

axes[1].plot(y,x)

plt.tight_layout()

# %% [markdown]
# You can save the plot as an image file like png, jpg, etc

# %%
fig.savefig("my_picture.png", dp1 = 200)

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

ax.set_title("Title")
ax.set_ylabel("Y")
ax.set_xlabel("X")

# %% [markdown]
# For the legend, you can specify the location in the arguments.

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,x**2, label = "X Squared")
ax.plot(x,x**3, label = "X Cubed")

ax.legend() 
plt.show()

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color = "orange", linewidth = 20, alpha = 0.5, linestyle = "--") #RGB Hex Codes are also accepted

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x,y, color = "orange", linewidth = 1, alpha = 0.5, linestyle = "--", marker = "o",markersize = 10, markerfacecolor = "yellow",\
        markeredgewidth =3, markeredgecolor ="green")

ax.set_xlim(0,1)
ax.set_ylim(0,2)
plt.show()

# %% [markdown]
# ### Matplotlib Exercises

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.show()

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.plot(x,y)
ax.set_title("X Squared Plot")
ax.set_xlabel("X Series")
ax.set_ylabel("Y Series")

plt.show()

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2])

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure()
axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([0.1,0.5,0.2,0.2])

axes1.plot(x,y)
axes2.plot(x,y)

axes1.set_title("Small Plot")
axes2.set_title("Large Plot")

axes1.set_xlabel("Large X Series")
axes2.set_xlabel("Small X Series")

axes1.set_ylabel("Large Y Series")
axes2.set_ylabel("Small y Series")
# Out:
# Text(0, 0.5, 'Small y Series')

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()

axes1 = fig.add_axes([0,0,1,1])
axes2 = fig.add_axes([0.2,0.5,0.4,0.4])

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig = plt.figure()

axes_1 = fig.add_axes([0,0,1,1])
axes_2 = fig.add_axes([0.2,0.5,0.4,0.4])

axes_1.set_title("Large Plot")
axes_2.set_title("Small Plot")

axes_1.set_xlabel("X awesome")
axes_1.set_ylabel("Y awesome")

axes_2.set_xlabel("X wild")
axes_2.set_ylabel("Y wild")

axes_2.set_xlim(20,50)
axes_2.set_ylim(30,50)



axes_1.plot(x,z)
axes_2.plot(x,y)

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %% [markdown]
# ## <en><center>Seaborn Visualizations</center></en>

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %% [markdown]
# #### Dataset

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ### Distribution Plots

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %% [markdown]
# #### Displot

# %%
sns.displot(tips["total_bill"], kde = False, bins = 30)
plt.show()

# %% [markdown]
# #### Joint Plot

# %%
sns.jointplot(x= 'total_bill', y= "tip", data = tips,kind = "hex",)
plt.show()

# %%
sns.jointplot(x= 'total_bill', y= "tip", data = tips,kind = "reg",)
plt.show()

# %%
sns.jointplot(x= 'total_bill', y= "tip", data = tips,kind = "kde",)
plt.show()

# %% [markdown]
# #### Pairplot

# %% [markdown]
# The Hue argument takes in a categorical column.

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = "sex", palette = "coolwarm")
plt.show()

# %% [markdown]
# #### Rugplot

# %%
sns.rugplot(tips["total_bill"])
plt.show()

# %%
sns.displot(tips["total_bill"],kde = False)
plt.show()

# %% [markdown]
# #### KDE Plot

# %%
sns.kdeplot(tips["total_bill"])
plt.show()

# %% [markdown]
# ### Categorical Plots

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %% [markdown]
# #### Dataset

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# #### Bar Plot

# %% [markdown]
# The estimator argument can apply aggregate functions.
# - Even your own custom functions.

# %%
sns.barplot(x = "sex", y = "total_bill" , data = tips, estimator = np.std)
plt.show()

# %% [markdown]
# #### Count Plot

# %%
sns.countplot(x = "sex", data = tips)
plt.show()

# %% [markdown]
# #### Box Plot

# %% [markdown]
# For a box plot: X = Categorical Data & Y = Quantitative Data

# %%
sns.boxplot(x = "day", y = "total_bill", data = tips, hue = "smoker")
plt.show()

# %% [markdown]
# #### Violin Plot

# %% [markdown]
# X = Categorical Data & Y = Quantitative Data
#
# The "split" argument splits the violin plot into 2 distributions according to the hue.
#
# Box Plot vs Violin Plot
#
# Pros:
# - The Violin plot displays more infomation.
# - It also shows the distribution of the data points.
#
# Cons:
# - A box plot is easier to read and understand the underlying data.

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips, hue = "sex", split= True)
plt.show()

# %% [markdown]
# #### Strip Plot

# %% [markdown]
# - The Jitter argument adds noise to the plot that make it easier to see the data points.
# - The dodge argument is the same as the split argument.

# %%
sns.stripplot(x = "day",y = "total_bill", data = tips,jitter = True, hue = 'sex', dodge = True)
plt.show()

# %% [markdown]
# #### Swarm Plot

# %% [markdown]
# Combine a swarm plot with a violin plot by having the violin plot in the same cell.
#
# - The swarm plot does not scale very well with large datasets.
# - It does not show very well the number of data points.
# - It also takes a lot of computational power to arrange the points.
# - Moreover, not very many people are familiar with this type of plot.

# %%
sns.violinplot(x = "day", y = "total_bill", data = tips)
sns.swarmplot(x = "day", y = "total_bill", data = tips, color = "black")
plt.show()

# %% [markdown]
# The catplot can recreate every other plot.

# %%
sns.catplot(x = "day", y = "total_bill", data = tips, kind = "bar")
plt.show()

# %% [markdown]
# ### Matrix Plots

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %% [markdown]
# #### Dataset

# %%
tips = sns.load_dataset("tips")
flights = sns.load_dataset("flights")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tc = tips.corr()

# %%
sns.heatmap(tc, annot = True, cmap = "coolwarm")
plt.show()

# %%
fp = flights.pivot_table(index = "month", columns = "year", values = "passengers")

# %%
sns.heatmap(fp, cmap = "magma", linecolor = "black",linewidths = 1)
plt.show()

# %%
sns.heatmap(fp, cmap = "mako", linecolor = "black",linewidths = 1)
plt.show()

# %%
sns.clustermap(fp,cmap = "magma", linecolor = "black", linewidths = 1, standard_scale = 1)
plt.show()

# %% [markdown]
# ### Grids

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %% [markdown]
# Datasets

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)
plt.show()

# %% [markdown]
# #### PairGrid

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.histplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

plt.show()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# #### FacetGrid

# %%
f = sns.FacetGrid(data = tips,col = "time", row = "smoker" )
f.map(sns.histplot, "total_bill", kde = True)
plt.show()

# %%
f = sns.FacetGrid(data = tips,col = "time", row = "smoker" )
f.map(plt.scatter, "total_bill", "tip")
plt.show()

# %% [markdown]
# ### Regression Plots

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %% [markdown]
# #### Dataset

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x = "total_bill", y = "tip", data = tips, hue = "sex",\
          markers = ["o", "v"], scatter_kws = {"s":100})

# %%
sns.lmplot(x = "total_bill", y = "tip", data = tips, col = "day",\
          row = "time", hue = "sex", aspect = 0.6, height = 3)

# %% [markdown]
# ### Style & Color

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %% [markdown]
# Dataset

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_style("ticks")
sns.countplot(x = "sex", data = tips)
plt.show()

# %%
sns.set_style("darkgrid")
sns.countplot(x = "sex", data = tips)
plt.show()

# %%
sns.set_style("whitegrid")
sns.countplot(x = "sex", data = tips)
plt.show()

# %%
sns.set_style("ticks")
sns.countplot(x = "sex", data = tips)
sns.despine()
plt.show()

# %%
plt.figure(figsize = (12,3))
sns.countplot(x = "sex", data = tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_context("notebook",font_scale = 2)
sns.countplot(x = "sex", data = tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x= "total_bill", y = "tip", data = tips, hue = "sex", palette = "seismic")

# %% [markdown]
# ### Seaborn Visualization Practice

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.jointplot(x = "fare",y = "age", data = titanic)
plt.show()

# %%
sns.displot(titanic["age"])

# %%
sns.displot(titanic["fare"],bins = 30, color = "red")

# %%
sns.boxplot(x = "class", y = "age", data = titanic)
# Out:
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.swarmplot(x = "class", y = "age", data = titanic, palette = "Set2")
# Out:
# C:\Users\pyria\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 15.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='class', ylabel='age'>

# %%
sns.barplot(x = "sex", y = "age", data = titanic)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='age'>

# %%
titanic.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(titanic.corr(), cmap = "magma", linecolor = "black", linewidth = 1)
# Out:
# <AxesSubplot:>

# %%
g = sns.FacetGrid(data = titanic, col = "sex")
g.map(plt.hist,"age")

# %% [markdown]
# ## Pandas Data Visualization

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %% [markdown]
# #### Dataset

# %%
df1 = pd.read_csv("C:\\Users\\pyria\\OneDrive\\Documents\Personal Development\\Python\\\
Bootcamps\\Py-DS-ML-Bootcamp\\Refactored_Py_DS_ML_Bootcamp-master\\07-Pandas-Built-in-Data-Viz\\df1", index_col = 0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv("C:\\Users\\pyria\\OneDrive\\Documents\Personal Development\\Python\\\
Bootcamps\\Py-DS-ML-Bootcamp\\Refactored_Py_DS_ML_Bootcamp-master\\07-Pandas-Built-in-Data-Viz\\df2")

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1["A"].hist(bins = 30)
# Out:
# <AxesSubplot:>

# %%
df1["A"].plot(kind= "hist", bins = 30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1["A"].plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area(alpha = 0.4)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x = "A", y = "B", s = df1["C"] * 50 )
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436
# ...              ...       ...       ...       ...
# 2002-09-22  1.013897 -0.288680 -0.342295 -0.638537
# 2002-09-23 -0.642659 -0.104725 -0.631829 -0.909483
# 2002-09-24  0.370136  0.233219  0.535897 -1.552605
# 2002-09-25  0.183339  1.285783 -1.052593 -2.565844
# 2002-09-26  0.775133 -0.850374  0.486728 -1.053427
#
# [1000 rows x 4 columns]

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns= ["a", "b"])

# %%
df.plot.hexbin(x = "a", y = "b", gridsize = 25, cmap = "magma")
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2["a"].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Plotly & Cufflinks

# %% [markdown]
# ![Mango.png](attachment:5b8e7d93-6a5e-4c1e-830b-7f5ef9795257.png)

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 5.6.0

# %%
df = pd.DataFrame(np.random.randn(100,4), columns = "A B C D".split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.609786  0.256619 -0.787480 -0.241078
# 1 -0.649079  1.929821  0.511915 -1.538480
# 2 -1.237792  1.057288 -0.096729  0.661488
# 3 -0.041851 -0.400798 -1.530179  0.312886
# 4  2.084331 -2.504731  0.227947  0.117261

# %%
df2 = pd.DataFrame({"Category":["A", "B","C"], "Values": [32, 43, 50]})

# %%
df.iplot()

# %% [markdown]
# #### Scatter Plot

# %%
df.iplot(kind = "scatter", x = "A", y = "B", mode = "markers" )

# %% [markdown]
# #### Bar plots

# %%
df2.iplot(kind = "bar", x = "Category", y = "Values")

# %%
df
# Out:
#            A         B         C         D
# 0   0.609786  0.256619 -0.787480 -0.241078
# 1  -0.649079  1.929821  0.511915 -1.538480
# 2  -1.237792  1.057288 -0.096729  0.661488
# 3  -0.041851 -0.400798 -1.530179  0.312886
# 4   2.084331 -2.504731  0.227947  0.117261
# ..       ...       ...       ...       ...
# 95  0.292113 -0.938443  0.476478  0.145219
# 96 -0.520281 -0.837248 -0.118573 -0.805062
# 97  0.889498 -0.168753 -0.722469  0.702400
# 98  1.174115  1.521901  0.908515 -0.330830
# 99  1.589664  1.661150  1.440334 -1.018399
#
# [100 rows x 4 columns]

# %%
df.sum().iplot(kind = "bar")

# %% [markdown]
# #### Box Plots

# %%
df.iplot(kind = "box")

# %% [markdown]
# #### Surface Area Plot

# %%
df3 = pd.DataFrame({"x":[1,2,3,4,5], "y": [10,20,30,20,10],\
                    "z": [5,4,3,2,1]})

# %%
df3.iplot(kind = "surface", colorscale = "rdylbu")

# %% [markdown]
# #### Histogram

# %%
df["A"].iplot(kind = "hist",bins = 50)

# %%
df.iplot(kind = "hist",bins = 50)

# %% [markdown]
# #### Spread

# %%
df[["A","B"]].iplot(kind = "spread")
# Out:
# C:\Users\pyria\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.
#
# C:\Users\pyria\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead.

# %% [markdown]
# #### Bubble Plot

# %%
df.iplot(kind = "bubble", x = "A", y = "B", size = "C")

# %% [markdown]
# #### Scatter Matrix Plot

# %% [markdown]
# - Make sure to take care with this plot as it uses alot of memory.
# - It may also crash the kernel if the dataset is too large.

# %%
df.scatter_matrix()
